# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import seaborn
from pandas import Series, DataFrame
import matplotlib.pyplot as plt

# %%
data= pd.read_csv("WPP2019_TotalPopulationBySex.csv",sep=",")

# %%
data
# Out:
#         LocID     Location  VarID      Variant  Time  MidPeriod    PopMale  \
# 0           4  Afghanistan      2       Medium  1950     1950.5   4099.243
# 1           4  Afghanistan      2       Medium  1951     1951.5   4134.756
# 2           4  Afghanistan      2       Medium  1952     1952.5   4174.450
# 3           4  Afghanistan      2       Medium  1953     1953.5   4218.336
# 4           4  Afghanistan      2       Medium  1954     1954.5   4266.484
# 5           4  Afghanistan      2       Medium  1955     1955.5   4318.945
# 6           4  Afghanistan      2       Medium  1956     1956.5   4375.800
# 7           4  Afghanistan      2       Medium  1957     1957.5   4437.157
# 8           4  Afghanistan      2       Medium  1958     1958.5   4503.156
# 9           4  Afghanistan      2       Medium  1959     1959.5   4573.914
# 10          4  Afghanistan      2       Medium  1960     1960.5   4649.573
# ...

# %%
data=data[(data.Time <= 2019)]
data=data.drop(['MidPeriod','Variant','VarID'],axis=1)
data.reindex()
# Out:
#         LocID     Location  Time   PopMale  PopFemale   PopTotal  PopDensity
# 0           4  Afghanistan  1950  4099.243   3652.874   7752.117      11.874
# 1           4  Afghanistan  1951  4134.756   3705.395   7840.151      12.009
# 2           4  Afghanistan  1952  4174.450   3761.546   7935.996      12.156
# 3           4  Afghanistan  1953  4218.336   3821.348   8039.684      12.315
# 4           4  Afghanistan  1954  4266.484   3884.832   8151.316      12.486
# 5           4  Afghanistan  1955  4318.945   3952.047   8270.992      12.669
# 6           4  Afghanistan  1956  4375.800   4023.073   8398.873      12.865
# 7           4  Afghanistan  1957  4437.157   4098.000   8535.157      13.073
# 8           4  Afghanistan  1958  4503.156   4176.941   8680.097      13.295
# 9           4  Afghanistan  1959  4573.914   4260.033   8833.947      13.531
# 10          4  Afghanistan  1960  4649.573   4347.394   8996.967      13.781
# ...

# %% [markdown]
# Nous coupons les prédictions de population pour garder uniquement la population réelle par location

# %%
data=data[data.LocID < 895]
data.reindex()
# Out:
#         LocID     Location  Time   PopMale  PopFemale   PopTotal  PopDensity
# 0           4  Afghanistan  1950  4099.243   3652.874   7752.117      11.874
# 1           4  Afghanistan  1951  4134.756   3705.395   7840.151      12.009
# 2           4  Afghanistan  1952  4174.450   3761.546   7935.996      12.156
# 3           4  Afghanistan  1953  4218.336   3821.348   8039.684      12.315
# 4           4  Afghanistan  1954  4266.484   3884.832   8151.316      12.486
# 5           4  Afghanistan  1955  4318.945   3952.047   8270.992      12.669
# 6           4  Afghanistan  1956  4375.800   4023.073   8398.873      12.865
# 7           4  Afghanistan  1957  4437.157   4098.000   8535.157      13.073
# 8           4  Afghanistan  1958  4503.156   4176.941   8680.097      13.295
# 9           4  Afghanistan  1959  4573.914   4260.033   8833.947      13.531
# 10          4  Afghanistan  1960  4649.573   4347.394   8996.967      13.781
# ...

# %% [markdown]
#         Objectif :
#
# les 5 locations les plus peuplés en 2019
#
# les 10 dernieres location les plus densement peuplé ( égale au 10 premieres locations les moins densement peuplé ) en 2019
#
# moyennes de la densité de population mondiale en 2000
#
#
# graphique de la densité de population en france au cours des années
#
# graphique le nombre de population masculine mondiale au cours des années
#
# graphique l'évolution de la population du Zimbabwe entre 1950 et 2000
#
# la moyenne et le nombre maximum de densité de population et de la population Total, en 2019

# %%
data[(data.Time==2019)].sort_values(by="PopTotal")[-5:]
# Out:
#         LocID                  Location  Time     PopMale   PopFemale  \
# 192381    586                  Pakistan  2019  111447.581  105117.736
# 116829    360                 Indonesia  2019  136269.761  134355.806
# 264290    840  United States of America  2019  162826.299  166238.618
# 115945    356                     India  2019  710129.572  656288.184
# 47893     156                     China  2019  735624.259  698159.433
#
#            PopTotal  PopDensity
# 192381   216565.317     280.933
# 116829   270625.567     149.387
# 264290   329064.917      35.974
# 115945  1366417.756     459.580
# 47893   1433783.692     152.722

# %%
data[(data.Time==2019)].sort_values(by="PopTotal")[:10]
# Out:
#         LocID                     Location  Time  PopMale  PopFemale  \
# 112409    336                     Holy See  2019      NaN        NaN
# 246478    772                      Tokelau  2019      NaN        NaN
# 179681    570                         Niue  2019      NaN        NaN
# 90136     238  Falkland Islands (Malvinas)  2019      NaN        NaN
# 166248    500                   Montserrat  2019      NaN        NaN
# 213166    666    Saint Pierre and Miquelon  2019      NaN        NaN
# 209630    654                 Saint Helena  2019      NaN        NaN
# 208746    652             Saint Barthélemy  2019      NaN        NaN
# 172156    520                        Nauru  2019      NaN        NaN
# 272592    876    Wallis and Futuna Islands  2019      NaN        NaN
#
#         PopTotal  PopDensity
# 112409     0.815    1852.273
# 246478     1.330     133.000
# 179681     1.614       6.208
# 90136      3.372       0.277
# 166248     4.991      49.910
# ...

# %%
data[(data.Time==2000)].PopDensity.mean()
# Out:
# 366.83761276595743

# %%
plt.rcParams['figure.figsize'] = [15, 6] # Taille du graphique en pouces
plt.rcParams['figure.dpi'] = 200 # résolution en points par pouce
data[(data.Location=="France")].PopDensity.plot()

# %%
data.groupby(data.Time).PopMale.sum().plot()

# %%
data[data.Time <= 2000][data.Time >= 1950][data.Location == "Zimbabwe"].PopTotal.plot()
# Out:
# C:\Users\basti\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
# C:\Users\basti\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.

# %%
data[data.Time == 2019].agg({'PopTotal' : ["mean","max"],'PopDensity': ["mean","max"]})
# Out:
#           PopTotal    PopDensity
# mean  3.282327e+04    470.872072
# max   1.433784e+06  26152.349000
